# %%
from PlaneEnv import PlaneEnv
from stable_baselines3.common.env_checker import check_env

# %%
env = PlaneEnv()

# %%
check_env(env)
# Out:
# c:\Users\yuanj\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\env_checker.py:515: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 check_env(env)
#
# File c:\Users\yuanj\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\env_checker.py:535, in check_env(env, warn, skip_render_check)
#     532     return
#     534 # ============ Check the returned values ===============
# --> 535 _check_returned_values(env, observation_space, action_space)
#     537 # ==== Check the render method and the declared render modes ====
#     538 if not skip_render_check:
#
# ...
